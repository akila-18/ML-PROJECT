# %%
pip install notebook --upgrade
# Out:
# Requirement already satisfied: notebook in c:\users\welcome\anaconda3\lib\site-packages (6.3.0)
# Collecting notebook
#   Downloading notebook-6.5.3-py3-none-any.whl (529 kB)
# Requirement already satisfied: jinja2 in c:\users\welcome\anaconda3\lib\site-packages (from notebook) (2.11.3)
# Requirement already satisfied: pyzmq>=17 in c:\users\welcome\anaconda3\lib\site-packages (from notebook) (20.0.0)
# Requirement already satisfied: ipython-genutils in c:\users\welcome\anaconda3\lib\site-packages (from notebook) (0.2.0)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\welcome\anaconda3\lib\site-packages (from notebook) (1.5.1)
# Requirement already satisfied: jupyter-core>=4.6.1 in c:\users\welcome\anaconda3\lib\site-packages (from notebook) (4.7.1)
# Requirement already satisfied: argon2-cffi in c:\users\welcome\anaconda3\lib\site-packages (from notebook) (20.1.0)
# Collecting Send2Trash>=1.8.0
#   Downloading Send2Trash-1.8.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: nbformat in c:\users\welcome\anaconda3\lib\site-packages (from notebook) (5.1.3)
# Collecting nbclassic>=0.4.7
#   Downloading nbclassic-0.5.3-py3-none-any.whl (10.0 MB)
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\users\welcome\anaconda3\lib\site-packages (from notebook) (6.1.12)
# Requirement already satisfied: traitlets>=4.2.1 in c:\users\welcome\anaconda3\lib\site-packages (from notebook) (5.0.5)
# Requirement already satisfied: prometheus-client in c:\users\welcome\anaconda3\lib\site-packages (from notebook) (0.10.1)
# Requirement already satisfied: nbconvert>=5 in c:\users\welcome\anaconda3\lib\site-packages (from notebook) (6.0.7)
# Requirement already satisfied: ipykernel in c:\users\welcome\anaconda3\lib\site-packages (from notebook) (5.3.4)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\welcome\anaconda3\lib\site-packages (from notebook) (0.9.4)
# Requirement already satisfied: tornado>=6.1 in c:\users\welcome\anaconda3\lib\site-packages (from notebook) (6.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\welcome\appdata\roaming\python\python38\site-packages (from jupyter-client>=5.3.4->notebook) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\welcome\anaconda3\lib\site-packages (from jupyter-core>=4.6.1->notebook) (227)
# Collecting jupyter-server>=1.8
#   Downloading jupyter_server-2.5.0-py3-none-any.whl (366 kB)
# Collecting notebook-shim>=0.1.0
#   Downloading notebook_shim-0.2.2-py3-none-any.whl (13 kB)
# Collecting websocket-client
#   Downloading websocket_client-1.5.1-py3-none-any.whl (55 kB)
# Requirement already satisfied: packaging in c:\users\welcome\appdata\roaming\python\python38\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook) (23.0)
# Collecting nbformat
#   Downloading nbformat-5.8.0-py3-none-any.whl (77 kB)
# Collecting jupyter-client>=5.3.4
#   Downloading jupyter_client-8.1.0-py3-none-any.whl (102 kB)
# Collecting tornado>=6.1
#   Downloading tornado-6.2-cp37-abi3-win_amd64.whl (425 kB)
# Collecting jupyter-events>=0.4.0
#   Downloading jupyter_events-0.6.3-py3-none-any.whl (18 kB)
# Requirement already satisfied: pywinpty in c:\users\welcome\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook) (0.5.7)
# Collecting nbconvert>=5
#   Downloading nbconvert-7.2.10-py3-none-any.whl (275 kB)
# Collecting jupyter-core>=4.6.1
#   Downloading jupyter_core-5.3.0-py3-none-any.whl (93 kB)
# Collecting anyio>=3.1.0
#   Downloading anyio-3.6.2-py3-none-any.whl (80 kB)
# Collecting pyzmq>=17
#   Downloading pyzmq-25.0.2-cp38-cp38-win_amd64.whl (1.1 MB)
# Collecting traitlets>=4.2.1
#   Downloading traitlets-5.9.0-py3-none-any.whl (117 kB)
# Collecting jupyter-server-terminals
#   Downloading jupyter_server_terminals-0.4.4-py3-none-any.whl (13 kB)
# Requirement already satisfied: sniffio>=1.1 in c:\users\welcome\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook) (1.2.0)
# Requirement already satisfied: idna>=2.8 in c:\users\welcome\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook) (2.10)
# Collecting importlib-metadata>=4.8.3
#   Downloading importlib_metadata-6.1.0-py3-none-any.whl (21 kB)
# Requirement already satisfied: zipp>=0.5 in c:\users\welcome\appdata\roaming\python\python38\site-packages (from importlib-metadata>=4.8.3->jupyter-client>=5.3.4->notebook) (3.15.0)
# Collecting pywin32>=1.0
#   Downloading pywin32-306-cp38-cp38-win_amd64.whl (9.4 MB)
# Collecting platformdirs>=2.5
#   Downloading platformdirs-3.2.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\welcome\anaconda3\lib\site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook) (5.4.1)
# Collecting python-json-logger>=2.0.4
#   Downloading python_json_logger-2.0.7-py3-none-any.whl (8.1 kB)Note: you may need to restart the kernel to use updated packages.
# WARNING: jsonschema 3.2.0 does not provide the extra 'format-nongpl'
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\welcome\\anaconda3\\Lib\\site-packages\\win32\\_win32sysloader.pyd'
# Consider using the `--user` option or check the permissions.
# Requirement already satisfied: jsonschema[format-nongpl]>=3.2.0 in c:\users\welcome\anaconda3\lib\site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook) (3.2.0)
# Collecting rfc3339-validator
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Collecting rfc3986-validator>=0.1.1
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\welcome\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=3.2.0->jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook) (20.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\welcome\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=3.2.0->jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook) (0.17.3)
# Requirement already satisfied: six>=1.11.0 in c:\users\welcome\appdata\roaming\python\python38\site-packages (from jsonschema[format-nongpl]>=3.2.0->jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook) (1.16.0)
# Requirement already satisfied: setuptools in c:\users\welcome\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=3.2.0->jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook) (52.0.0.post20210125)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\welcome\anaconda3\lib\site-packages (from nbconvert>=5->notebook) (1.4.3)
# Requirement already satisfied: defusedxml in c:\users\welcome\anaconda3\lib\site-packages (from nbconvert>=5->notebook) (0.7.1)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\welcome\anaconda3\lib\site-packages (from nbconvert>=5->notebook) (2.8.1)
# Collecting jinja2
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
# Requirement already satisfied: bleach in c:\users\welcome\anaconda3\lib\site-packages (from nbconvert>=5->notebook) (3.3.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\welcome\anaconda3\lib\site-packages (from nbconvert>=5->notebook) (0.1.2)
# Collecting markupsafe>=2.0
#   Downloading MarkupSafe-2.1.2-cp38-cp38-win_amd64.whl (16 kB)
# Collecting mistune<3,>=2.0.3
#   Downloading mistune-2.0.5-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: beautifulsoup4 in c:\users\welcome\anaconda3\lib\site-packages (from nbconvert>=5->notebook) (4.9.3)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\welcome\anaconda3\lib\site-packages (from nbconvert>=5->notebook) (0.5.3)
# Collecting tinycss2
#   Downloading tinycss2-1.2.1-py3-none-any.whl (21 kB)
# Requirement already satisfied: async-generator in c:\users\welcome\anaconda3\lib\site-packages (from nbclient>=0.5.0->nbconvert>=5->notebook) (1.10)
# Collecting fastjsonschema
#   Downloading fastjsonschema-2.16.3-py3-none-any.whl (23 kB)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\welcome\anaconda3\lib\site-packages (from argon2-cffi->notebook) (1.14.5)
# Requirement already satisfied: pycparser in c:\users\welcome\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook) (2.20)
# Requirement already satisfied: soupsieve>1.2 in c:\users\welcome\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook) (2.2.1)
# Requirement already satisfied: webencodings in c:\users\welcome\anaconda3\lib\site-packages (from bleach->nbconvert>=5->notebook) (0.5.1)
# Requirement already satisfied: ipython>=5.0.0 in c:\users\welcome\anaconda3\lib\site-packages (from ipykernel->notebook) (7.22.0)
# Requirement already satisfied: decorator in c:\users\welcome\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel->notebook) (5.0.6)
# Requirement already satisfied: pickleshare in c:\users\welcome\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel->notebook) (0.7.5)
# Requirement already satisfied: backcall in c:\users\welcome\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel->notebook) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\welcome\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel->notebook) (3.0.17)
# Requirement already satisfied: colorama in c:\users\welcome\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel->notebook) (0.4.4)
# Requirement already satisfied: jedi>=0.16 in c:\users\welcome\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel->notebook) (0.17.2)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\welcome\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.0.0->ipykernel->notebook) (0.7.0)
# Requirement already satisfied: wcwidth in c:\users\welcome\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel->notebook) (0.2.5)
# Collecting pywinpty
#   Downloading pywinpty-2.0.10-cp38-none-win_amd64.whl (1.4 MB)
# Installing collected packages: traitlets, pywin32, platformdirs, tornado, pyzmq, jupyter-core, importlib-metadata, fastjsonschema, pywinpty, nbformat, markupsafe, jupyter-client, tinycss2, rfc3986-validator, rfc3339-validator, python-json-logger, mistune, jinja2, websocket-client, Send2Trash, nbconvert, jupyter-server-terminals, jupyter-events, anyio, jupyter-server, notebook-shim, nbclassic, notebook
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.0.5
#     Uninstalling traitlets-5.0.5:
#       Successfully uninstalled traitlets-5.0.5
#   Attempting uninstall: pywin32
#     Found existing installation: pywin32 227
#     Uninstalling pywin32-227:
#       Successfully uninstalled pywin32-227
#   Rolling back uninstall of pywin32
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\__pycache__\pythoncom.cpython-38.pyc
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-ox18eh1i\pythoncom.cpython-38.pyc
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\adodbapi
#    from C:\Users\welcome\anaconda3\Lib\site-packages\~dodbapi
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\isapi
#    from C:\Users\welcome\anaconda3\Lib\site-packages\~sapi
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pythoncom.py
#    from C:\Users\welcome\AppData\Local\Temp\pip-uninstall-ad8gjv5k\pythoncom.py
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pythonwin
#    from C:\Users\welcome\anaconda3\Lib\site-packages\~ythonwin
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\pywin32-227-py3.8.egg-info
#    from C:\Users\welcome\anaconda3\Lib\site-packages\~ywin32-227-py3.8.egg-info
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\win32\lib\
#    from C:\Users\welcome\anaconda3\Lib\site-packages\win32\~ib
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\win32com
#    from C:\Users\welcome\anaconda3\Lib\site-packages\~in32com
#   Moving to c:\users\welcome\anaconda3\lib\site-packages\win32comext
#    from C:\Users\welcome\anaconda3\Lib\site-packages\~in32comext

# %%
# Basic Import
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
# Modelling
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression, Ridge,Lasso
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.model_selection import RandomizedSearchCV
from catboost import CatBoostRegressor
from xgboost import XGBRegressor
import warnings
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 7
#       5 import seaborn as sns
#       6 # Modelling
# ----> 7 from sklearn.metrics import mean_squared_error, r2_score
#       8 from sklearn.neighbors import KNeighborsRegressor
#       9 from sklearn.tree import DecisionTreeRegressor
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
pip install catboost
# Out:
# Requirement already satisfied: catboost in c:\users\welcome\anaconda3\lib\site-packages (1.1.1)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: six in c:\users\welcome\appdata\roaming\python\python38\site-packages (from catboost) (1.16.0)
# Requirement already satisfied: plotly in c:\users\welcome\anaconda3\lib\site-packages (from catboost) (5.1.0)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\welcome\appdata\roaming\python\python38\site-packages (from catboost) (1.22.4)
# Requirement already satisfied: pandas>=0.24.0 in c:\users\welcome\anaconda3\lib\site-packages (from catboost) (1.2.4)
# Requirement already satisfied: scipy in c:\users\welcome\anaconda3\lib\site-packages (from catboost) (1.6.2)
# Requirement already satisfied: matplotlib in c:\users\welcome\appdata\roaming\python\python38\site-packages (from catboost) (3.7.1)
# Requirement already satisfied: graphviz in c:\users\welcome\anaconda3\lib\site-packages (from catboost) (0.20.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\welcome\appdata\roaming\python\python38\site-packages (from pandas>=0.24.0->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\welcome\anaconda3\lib\site-packages (from pandas>=0.24.0->catboost) (2021.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\welcome\appdata\roaming\python\python38\site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\welcome\appdata\roaming\python\python38\site-packages (from matplotlib->catboost) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\welcome\appdata\roaming\python\python38\site-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\welcome\appdata\roaming\python\python38\site-packages (from matplotlib->catboost) (5.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\welcome\appdata\roaming\python\python38\site-packages (from matplotlib->catboost) (4.39.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\welcome\appdata\roaming\python\python38\site-packages (from matplotlib->catboost) (1.0.7)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\welcome\appdata\roaming\python\python38\site-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\welcome\appdata\roaming\python\python38\site-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\welcome\appdata\roaming\python\python38\site-packages (from importlib-resources>=3.2.0->matplotlib->catboost) (3.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\welcome\anaconda3\lib\site-packages (from plotly->catboost) (8.0.1)

# %%
pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-1.7.4-py3-none-win_amd64.whl (89.1 MB)
# Requirement already satisfied: numpy in c:\users\welcome\appdata\roaming\python\python38\site-packages (from xgboost) (1.22.4)
# Requirement already satisfied: scipy in c:\users\welcome\anaconda3\lib\site-packages (from xgboost) (1.6.2)
# Installing collected packages: xgboost
# Successfully installed xgboost-1.7.4
# Note: you may need to restart the kernel to use updated packages.

# %%
df=pd.read_csv('F:/ML PROJECT/notebook/StudentsPerformance.csv')
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
X = df.drop(columns=['math score'],axis=1)
X.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  reading score  writing score
# 0                    none             72             74
# 1               completed             90             88
# 2                    none             95             93
# 3                    none             57             44
# 4                    none             78             75

# %%
Y=df['math score']
Y
# Out:
# 0      72
# 1      69
# 2      90
# 3      47
# 4      76
#        ..
# 995    88
# 996    62
# 997    59
# 998    68
# 999    77
# Name: math score, Length: 1000, dtype: int64

# %%
print("Categories in 'gender' variable:     ",end=" " )
print(df['gender'].unique())

print("Categories in 'race/ethnicity' variable:  ",end=" ")
print(df['race/ethnicity'].unique())

print("Categories in'parental level of education' variable:",end=" " )
print(df['parental level of education'].unique())

print("Categories in 'lunch' variable:     ",end=" " )
print(df['lunch'].unique())

print("Categories in 'test preparation course' variable:     ",end=" " )
print(df['test preparation course'].unique())
# Out:
# Categories in 'gender' variable:      ['female' 'male']
# Categories in 'race/ethnicity' variable:   ['group B' 'group C' 'group A' 'group D' 'group E']
# Categories in'parental level of education' variable: ["bachelor's degree" 'some college' "master's degree" "associate's degree"
#  'high school' 'some high school']
# Categories in 'lunch' variable:      ['standard' 'free/reduced']
# Categories in 'test preparation course' variable:      ['none' 'completed']

# %%
#create a column transformer with 3 types of transformers

num_features=X.select_dtypes(exclude='object').columns
cat_features=X.select_dtypes(include='object').columns

from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer

numeric_transformer=StandardScaler()
oh_transformer=OneHotEncoder()

preprocessor=ColumnTransformer(
    [
        ("OneHotEncoder", oh_transformer, cat_features),
         ("StandardScaler", numeric_transformer, num_features),   
    ]


)

# %%
X = preprocessor.fit_transform(X)

# %%
X.shape
# Out:
# (1000, 19)

# %%
#seperate dataset with train and test split

from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2,random_state=42)
X_train.shape, X_test.shape
# Out:
# ((800, 19), (200, 19))

# %% [markdown]
# ### Create an evaluate function to give all metrics on model training

# %%
def evaluate_model(true,predicted):
    mae=mean_absolute_error(true,predicted)
    mse=mean_squared_error(true,predicted)
    rmse=np.sqrt(mean_squared_error(true,predicted))
    r2_square=r2_score(true,predicted)
    return mse,rmse,r2_square

# %%
models = {
    "Linear Regression": LinearRegression(),
    "Lasso": Lasso(),
    "Ridge": Ridge(),
    "K-Neighbors Regressor": KNeighborsRegressor(),
    "Decision Tree": DecisionTreeRegressor(),
    "Random Forest Regressor": RandomForestRegressor(),
    "XGBRegressor": XGBRegressor(), 
    "CatBoosting Regressor": CatBoostRegressor(verbose=False),
    "AdaBoost Regressor": AdaBoostRegressor()
}
model_list = []
r2_list =[]

for i in range(len(list(models))):
    model = list(models.values())[i]
    model.fit(X_train, Y_train) # Train model

    # Make predictions
    Y_train_pred = model.predict(X_train)
    Y_test_pred = model.predict(X_test)
    
    # Evaluate Train and Test dataset
    model_train_mae , model_train_rmse, model_train_r2 = evaluate_model(Y_train, Y_train_pred)

    model_test_mae , model_test_rmse, model_test_r2 = evaluate_model(Y_test, Y_test_pred)

    
    print(list(models.keys())[i])
    model_list.append(list(models.keys())[i])
    
    print('Model performance for Training set')
    print("- Root Mean Squared Error: {:.4f}".format(model_train_rmse))
    print("- Mean Absolute Error: {:.4f}".format(model_train_mae))
    print("- R2 Score: {:.4f}".format(model_train_r2))

    print('----------------------------------')
    
    print('Model performance for Test set')
    print("- Root Mean Squared Error: {:.4f}".format(model_test_rmse))
    print("- Mean Absolute Error: {:.4f}".format(model_test_mae))
    print("- R2 Score: {:.4f}".format(model_test_r2))
    r2_list.append(model_test_r2)
    
    print('='*35)
    print('\n')
# Out:
# Linear Regression
# Model performance for Training set
# - Root Mean Squared Error: 5.3231
# - Mean Absolute Error: 28.3349
# - R2 Score: 0.8743
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 5.3940
# - Mean Absolute Error: 29.0952
# - R2 Score: 0.8804
# ===================================
#
#
# Lasso
# Model performance for Training set
# - Root Mean Squared Error: 6.5938
# - Mean Absolute Error: 43.4784
# - R2 Score: 0.8071
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 6.5197
# - Mean Absolute Error: 42.5064
# - R2 Score: 0.8253
# ===================================
#
#
# Ridge
# Model performance for Training set
# - Root Mean Squared Error: 5.3233
# - Mean Absolute Error: 28.3378
# - R2 Score: 0.8743
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 5.3904
# - Mean Absolute Error: 29.0563
# - R2 Score: 0.8806
# ===================================
#
#
# K-Neighbors Regressor
# Model performance for Training set
# - Root Mean Squared Error: 5.7055
# - Mean Absolute Error: 32.5523
# - R2 Score: 0.8556
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 7.2634
# - Mean Absolute Error: 52.7574
# - R2 Score: 0.7832
# ===================================
#
#
# Decision Tree
# Model performance for Training set
# - Root Mean Squared Error: 0.2795
# - Mean Absolute Error: 0.0781
# - R2 Score: 0.9997
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 7.6318
# - Mean Absolute Error: 58.2450
# - R2 Score: 0.7606
# ===================================
#
#
# Random Forest Regressor
# Model performance for Training set
# - Root Mean Squared Error: 2.2832
# - Mean Absolute Error: 5.2132
# - R2 Score: 0.9769
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 6.0198
# - Mean Absolute Error: 36.2380
# - R2 Score: 0.8511
# ===================================
#
#
# XGBRegressor
# Model performance for Training set
# - Root Mean Squared Error: 0.9087
# - Mean Absolute Error: 0.8258
# - R2 Score: 0.9963
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 6.5889
# - Mean Absolute Error: 43.4141
# - R2 Score: 0.8216
# ===================================
#
#
# CatBoosting Regressor
# Model performance for Training set
# - Root Mean Squared Error: 3.0427
# - Mean Absolute Error: 9.2578
# - R2 Score: 0.9589
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 6.0086
# - Mean Absolute Error: 36.1037
# - R2 Score: 0.8516
# ===================================
#
#
# AdaBoost Regressor
# Model performance for Training set
# - Root Mean Squared Error: 5.8390
# - Mean Absolute Error: 34.0940
# - R2 Score: 0.8488
# ----------------------------------
# Model performance for Test set
# - Root Mean Squared Error: 6.1800
# - Mean Absolute Error: 38.1919
# - R2 Score: 0.8431
# ===================================

# %% [markdown]
# ### Results

# %%
pd.DataFrame(list(zip(model_list, r2_list)), columns=['Model Name', 'R2_Score']).sort_values(by=["R2_Score"],ascending=False)
# Out:
#                 Model Name  R2_Score
# 2                    Ridge  0.880593
# 0        Linear Regression  0.880433
# 7    CatBoosting Regressor  0.851632
# 5  Random Forest Regressor  0.851080
# 8       AdaBoost Regressor  0.843050
# 1                    Lasso  0.825320
# 6             XGBRegressor  0.821589
# 3    K-Neighbors Regressor  0.783193
# 4            Decision Tree  0.760642

# %% [markdown]
# ## Linear Regression

# %%
lin_model = LinearRegression(fit_intercept=True)
lin_model = lin_model.fit(X_train, Y_train)
Y_pred = lin_model.predict(X_test)
score = r2_score(Y_test, Y_pred)*100
print(" Accuracy of the model is %.2f" %score)
# Out:
#  Accuracy of the model is 88.04

# %% [markdown]
# Plot Y-pred and Y-test

# %%
plt.scatter(Y_test,Y_pred);
plt.xlabel('Actual');
plt.ylabel('Predicted');

# %%
sns.regplot(x=Y_test,y=Y_pred,ci=None,color ='yellow');

# %% [markdown]
# ## difference between actual and predict values

# %%
pred_df=pd.DataFrame({'Actual Value':Y_test,'Predicted Value':Y_pred,'Difference':Y_test-Y_pred})
pred_df
# Out:
#      Actual Value  Predicted Value  Difference
# 521            91        76.387970   14.612030
# 737            53        58.885970   -5.885970
# 740            80        76.990265    3.009735
# 660            74        76.851804   -2.851804
# 411            84        87.627378   -3.627378
# ..            ...              ...         ...
# 408            52        43.409149    8.590851
# 332            62        62.152214   -0.152214
# 208            74        67.888395    6.111605
# 613            65        67.022287   -2.022287
# 78             61        62.345132   -1.345132
#
# [200 rows x 3 columns]
